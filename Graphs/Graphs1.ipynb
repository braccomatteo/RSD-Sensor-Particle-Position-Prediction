# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

"""
Data obtained by means of RandomForest extrapolating from multiple_regressor.estimators[0/1].feature_importances_ 
"""

def log10(x):
    return np.log(x) / np.log(10)

fig, axs = plt.subplots(1, 2, figsize=(12,6))

features_names_importance_x = [
    ('pmax[8]', 0.8005137210728225),
('pmax[13]', 0.1087823392019065),
('pmax[5]', 0.021410038958375018),
('pmax[10]', 0.015989697148897888),
('pmax[1]', 0.015151060494938896),
('pmax[14]', 0.012158020353899589),
('negpmax[3]', 0.004577806010692508),
('pmax[15]', 0.004025981161685748),
('negpmax[10]', 0.0026519648250360006),
('negpmax[6]', 0.0021760118529112636),
('negpmax[5]', 0.0020134608576579636),
('negpmax[8]', 0.0016580839804271777),
('negpmax[1]', 0.0013496200919512046),
('negpmax[13]', 0.00127737754192582),
('negpmax[9]', 0.0012213888541260742),
('pmax[6]', 0.0010249445630257322),
('negpmax[11]', 0.0009331667488864789),
('negpmax[14]', 0.0007818780149532564),
('pmax[3]', 0.000498736541832191),
('pmax[4]', 0.00038532986913088766),
('pmax[11]', 0.0002910006233433687),
('pmax[2]', 0.00022408477457535765),
('pmax[9]', 0.00016372068170327668),
('negpmax[4]', 8.861435655603175e-05),
('area[15]', 7.62788342602447e-05),
('area[5]', 7.247333858838347e-05),
('area[14]', 6.601714694671309e-05),
('area[10]', 5.707997500654829e-05),
('area[13]', 4.850863364579967e-05),
('area[3]', 4.235372939173743e-05),
('area[6]', 2.431897110761622e-05),
('area[8]', 2.3599201807774578e-05),
('area[1]', 2.2997779935199405e-05),
('area[11]', 2.2221970434156152e-05),
('negpmax[2]', 2.1458087371215596e-05),
('area[9]', 1.3620160533277245e-05),
('area[4]', 1.3136400398806383e-05),
('negpmax[17]', 8.08585920708409e-06),
('area[2]', 7.795966193994731e-06),
('pmax[12]', 7.184185081702712e-06),
('pmax[0]', 5.72580524020069e-06),
('pmax[7]', 5.592536825728108e-06),
('negpmax[16]', 4.708027199623172e-06),
('pmax[16]', 4.142154631249906e-06),
('area[16]', 3.5778626854712346e-06),
('area[17]', 3.4338470165942236e-06),
('pmax[17]', 3.1274094726396238e-06),
('negpmax[15]', 2.9827564895845837e-06),
('area[7]', 2.8447310044933923e-06),
('rms[14]', 2.8102564372218865e-06),
('negpmax[12]', 2.7994135181593277e-06),
('rms[2]', 2.698389931649537e-06),
('rms[10]', 2.6507225303445917e-06),
('rms[3]', 2.6282785737701126e-06),
('rms[16]', 2.6023611266628017e-06),
('rms[6]', 2.5969005956767164e-06),
('negpmax[7]', 2.5809656331651974e-06),
('area[12]', 2.5753503779348515e-06),
('rms[11]', 2.5582031587961645e-06),
('negpmax[0]', 2.5418361317310363e-06),
('tmax[7]', 2.5319589940567688e-06),
('rms[8]', 2.5200160851422205e-06),
('rms[17]', 2.4980199221221164e-06),
('tmax[6]', 2.4779254598289727e-06),
('rms[0]', 2.473479615496998e-06),
('rms[13]', 2.4728526881362156e-06),
('rms[5]', 2.4614913893418316e-06),
('rms[15]', 2.402539006480661e-06),
('rms[1]', 2.3929214888552526e-06),
('rms[9]', 2.365590857606251e-06),
('area[0]', 2.351147911843114e-06),
('rms[7]', 2.318250717414897e-06),
('rms[4]', 2.3129719504276473e-06),
('rms[12]', 2.303898443158617e-06),
('tmax[9]', 2.1538368889064087e-06),
('tmax[12]', 2.1363024309093554e-06),
('tmax[0]', 2.068337779513406e-06),
('tmax[2]', 1.828246407197116e-06),
('tmax[5]', 1.7922908046976403e-06),
('tmax[1]', 1.7904016090145832e-06),
('tmax[4]', 1.744180976834915e-06),
('tmax[14]', 1.7208467625975548e-06),
('tmax[15]', 1.591596823380023e-06),
('tmax[10]', 1.4711750840812502e-06),
('tmax[16]', 1.3890296241130936e-06),
('tmax[8]', 1.3603605419957953e-06),
('tmax[11]', 1.359143444137483e-06),
('tmax[17]', 1.2797854148098656e-06),
('tmax[3]', 1.2667463071974843e-06),
('tmax[13]', 8.080248188991782e-07)
]

features_names_importance_x = sorted(features_names_importance_x, key=lambda x: x[0])
features_names, features_importance = zip(*features_names_importance_x)
features_names_summedup = [features_names[0:18], features_names[18:36], features_names[36:54], features_names[54:72], features_names[72:90] ]
features_importance_summedup = [np.log10(features_importance[0:18]), np.log10(features_importance[18:36]), np.log10(features_importance[36:54]), np.log10(features_importance[54:72]), np.log10(features_importance[72:90]) ]

for names,importances in zip(features_names_summedup, features_importance_summedup):
    name = (names[0]).split("[")[0]
    axs[0].scatter([name]*len(names), importances, label=name, alpha=0.7) 

plt.subplot(1,2,1)
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.xlabel("Feature Names")
plt.ylabel("Feature Importances (log10)")

axs[0].set_title("x coordinate") 
axs[0].legend()

features_names_importance_y = [
    ('pmax[4]', 0.628433979204202),
    ('pmax[10]', 0.14500631802541952),
    ('pmax[3]', 0.08335254686041438),
    ('pmax[5]', 0.04497261510295889),
    ('negpmax[13]', 0.027016768578270157),
    ('pmax[13]', 0.019797494165305084),
    ('pmax[11]', 0.0172580116069593),
    ('negpmax[10]', 0.010296229955837235),
    ('negpmax[5]', 0.005192366300355212),
    ('negpmax[3]', 0.004917183361007402),
    ('negpmax[11]', 0.004878074863743001),
    ('negpmax[4]', 0.001677635437829895),
    ('pmax[8]', 0.0014439974060981096),
    ('pmax[15]', 0.0009693070500243638),
    ('area[10]', 0.000912953915303888),
    ('area[15]', 0.0008225512656120208),
    ('negpmax[8]', 0.0006209242157711876),
    ('pmax[14]', 0.00044853613063792146),
    ('negpmax[9]', 0.00026491593881042903),
    ('pmax[9]', 0.00020509593938539507),
    ('area[3]', 0.0001918981621165106),
    ('pmax[2]', 0.00015711376296275584),
    ('area[5]', 0.00012303804700400332),
    ('pmax[1]', 0.00011374881927320144),
    ('negpmax[1]', 0.00011183925486110077),
    ('area[13]', 0.00010949504122072007),
    ('negpmax[14]', 0.00010665594098982014),
    ('pmax[6]', 7.484095987951464e-05),
    ('negpmax[6]', 5.870109237457427e-05),
    ('area[11]', 4.991532388474017e-05),
    ('negpmax[2]', 4.325278699952825e-05),
    ('area[4]', 2.8742268501960588e-05),
    ('area[8]', 2.8416010276748074e-05),
    ('area[9]', 1.729422581526414e-05),
    ('area[14]', 1.61859024318176e-05),
    ('area[6]', 1.280387333851884e-05),
    ('pmax[16]', 1.2801068548235759e-05),
    ('area[1]', 1.2615268297400712e-05),
    ('tmax[5]', 1.2085502192812458e-05),
    ('negpmax[17]', 9.625803882306647e-06),
    ('area[16]', 8.722650119797505e-06),
    ('negpmax[16]', 7.749253421622002e-06),
    ('pmax[17]', 7.545935123197544e-06),
    ('tmax[4]', 6.853330797326025e-06),
    ('pmax[7]', 6.6517735434579186e-06),
    ('pmax[12]', 6.4420718560593475e-06),
    ('area[17]', 6.4406219057453025e-06),
    ('area[2]', 6.207153234706153e-06),
    ('rms[16]', 6.1058048096063104e-06),
    ('pmax[0]', 5.355569391128516e-06),
    ('tmax[3]', 4.9764329794471925e-06),
    ('negpmax[12]', 4.945993234200948e-06),
    ('negpmax[15]', 4.818269403779363e-06),
    ('negpmax[0]', 4.72958076210525e-06),
    ('negpmax[7]', 4.6304546524351846e-06),
    ('rms[17]', 4.597795920510053e-06),
    ('rms[6]', 4.594695324009065e-06),
    ('rms[0]', 4.573395407657622e-06),
    ('rms[8]', 4.5700361204758335e-06),
    ('rms[12]', 4.492594926582275e-06),
    ('rms[5]', 4.472424219106448e-06),
    ('rms[13]', 4.446325119112513e-06),
    ('area[12]', 4.401051676398694e-06),
    ('rms[3]', 4.357401634390097e-06),
    ('rms[10]', 4.319577461566748e-06),
    ('rms[7]', 4.318790381510746e-06),
    ('rms[4]', 4.295408837482854e-06),
    ('rms[15]', 4.2881246708989506e-06),
    ('rms[9]', 4.2674519311971245e-06),
    ('rms[1]', 4.204735448405477e-06),
    ('area[0]', 4.168384819923565e-06),
    ('rms[11]', 4.160793846542638e-06),
    ('rms[2]', 4.157294449033766e-06),
    ('area[7]', 4.141680415207002e-06),
    ('rms[14]', 4.063138136721077e-06),
    ('tmax[7]', 3.949521054076664e-06),
    ('tmax[0]', 3.930145121642938e-06),
    ('tmax[12]', 3.8527531627323675e-06),
    ('tmax[6]', 3.650230657039797e-06),
    ('tmax[16]', 3.142327289118452e-06),
    ('tmax[2]', 3.1300716048947944e-06),
    ('tmax[9]', 3.038111583567431e-06),
    ('tmax[14]', 2.8715280841189727e-06),
    ('tmax[15]', 2.847922715248128e-06),
    ('tmax[1]', 2.6130698316593787e-06),
    ('tmax[8]', 2.3478330005291957e-06),
    ('tmax[17]', 2.320903974661524e-06),
    ('tmax[11]', 2.1307124462177254e-06),
    ('tmax[13]', 1.365417202135017e-06),
    ('tmax[10]', 1.1690174941644778e-06)
]

features_names_importance_y = sorted(features_names_importance_y, key=lambda x: x[0])
features_names, features_importance = zip(*features_names_importance_y)
features_names_summedup = [features_names[0:18], features_names[18:36], features_names[36:54], features_names[54:72], features_names[72:90] ]
features_importance_summedup = [np.log10(features_importance[0:18]), np.log10(features_importance[18:36]), np.log10(features_importance[36:54]), np.log10(features_importance[54:72]), np.log10(features_importance[72:90]) ]

for names,importances in zip(features_names_summedup, features_importance_summedup):
    name = (names[0]).split("[")[0]
    axs[1].scatter([name]*len(names), importances, label=name, alpha=0.7) 

plt.subplot(1,2,2)
#plt.yticks(np.arange(0, 1.1, step=0.1)) 
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.xlabel("Feature Names")
plt.ylabel("Feature Importances (log10)")
    
axs[1].set_title("y coordinate")
axs[1].legend()

plt.savefig('feature_importances.png')
plt.show()
